# %% [markdown]
# # Revised internal evaluation
# Open this notebook from the extracted package directory. Install requirements.txt into this kernel first. The code cell invokes run_analysis.py and regenerates results/. Original data provenance is unresolved. The delivered results were generated by the script; this launcher itself has not been executed in Jupyter.

# %%
from pathlib import Path
import run_analysis
assert Path("Data.csv").exists(), "Open the notebook from the package directory"
run_analysis.main(Path("Data.csv"))
